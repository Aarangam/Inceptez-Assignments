# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv("Demand_txn_updated.txt")

# %% [markdown]
# ## 1st question Returning First 15 Rows of Data

# %%
df.head(15)
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0   Hyderabad         Take Away              9978        7/31/2018
# 1   Hyderabad         Take Away              4064        7/31/2018
# 2   Hyderabad         Main Hall               965        7/31/2018
# 3   Hyderabad           Express              9978        7/31/2018
# 4   Hyderabad           Express              1045        7/31/2018
# 5   Hyderabad          Delivery              4056        7/31/2018
# 6   Hyderabad         Take Away              4065        7/31/2018
# 7   Hyderabad           Express              4058        7/31/2018
# 8   Hyderabad           Express              4057        7/31/2018
# 9   Hyderabad           Express              4056        7/31/2018
# 10  Hyderabad          Delivery              4061        7/31/2018
# 11  Hyderabad           Express              4055        7/31/2018
# 12  Hyderabad         Take Away              4061        7/31/2018
# ...

# %% [markdown]
# ## question 1Shape of the Data

# %%
df.shape
# Out:
# (30231, 22)

# %% [markdown]
# ## Data types

# %%
df.dtypes
# Out:
# City                                           object
# Mapped_Sales_Type                              object
# Mapped_Item_Code                                int64
# Transaction_Date                               object
# Quantity_Sold                                   int64
# Median_Price                                  float64
# Average_Tax_Percent                           float64
# Effective_Price                               float64
# Percent_Quantity_With_Discount                float64
# Avg_Discount_Percent_On_Discounted_Items      float64
# Year                                            int64
# Month                                           int64
# Day                                            object
# Car_sales                                     float64
# F_and_B_Inflation                             float64
# F_and_B_Inflation_Adjusted_Effective_Price    float64
# F_and_B_Inflation_Adjusted_Median_Price       float64
# ...

# %% [markdown]
# ## 2nd question Changing "Transaction_date" Datatype into datetime

# %%
df["Transaction_Date"]
# Out:
# 0        7/31/2018
# 1        7/31/2018
# 2        7/31/2018
# 3        7/31/2018
# 4        7/31/2018
#            ...
# 30226     8/1/2016
# 30227     8/1/2016
# 30228     8/1/2016
# 30229     8/1/2016
# 30230     8/1/2016
# Name: Transaction_Date, Length: 30231, dtype: object

# %%
df['Transaction_Date'] = pd.to_datetime(df['Transaction_Date'], format='%m/%d/%Y')

# %%
df.dtypes
# Out:
# City                                                  object
# Mapped_Sales_Type                                     object
# Mapped_Item_Code                                       int64
# Transaction_Date                              datetime64[ns]
# Quantity_Sold                                          int64
# Median_Price                                         float64
# Average_Tax_Percent                                  float64
# Effective_Price                                      float64
# Percent_Quantity_With_Discount                       float64
# Avg_Discount_Percent_On_Discounted_Items             float64
# Year                                                   int64
# Month                                                  int64
# Day                                                   object
# Car_sales                                            float64
# F_and_B_Inflation                                    float64
# ...

# %% [markdown]
# ## 3rd question subset 1

# %%
df_subset1 = df.loc[df["Transaction_Date"] > '08/01/2016']
df_subset1.head()
# Out:
#         City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0  Hyderabad         Take Away              9978       2018-07-31
# 1  Hyderabad         Take Away              4064       2018-07-31
# 2  Hyderabad         Main Hall               965       2018-07-31
# 3  Hyderabad           Express              9978       2018-07-31
# 4  Hyderabad           Express              1045       2018-07-31
#
#    Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 0            167         187.0                 0.05       163.700000
# 1            368         602.0                 0.05       584.329105
# 2            694         263.0                 0.05       244.835163
# 3            140         263.0                 0.05       243.500000
# 4            139         392.0                 0.05       378.960000
#
#    Percent_Quantity_With_Discount  Avg_Discount_Percent_On_Discounted_Items  \
# ...

# %% [markdown]
# ## 4th question unique values

# %%
df["Mapped_Sales_Type"].unique()
# Out:
# array(['Take Away', 'Main Hall', 'Express', 'Delivery', 'Dine-in',
#        'Bakery'], dtype=object)

# %% [markdown]
# ## 5th question Subset 2

# %%
df_subset2 = df.loc[df["Avg_Discount_Percent_On_Discounted_Items"] < 1.0]
df_subset2
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 5      Hyderabad          Delivery              4056       2018-07-31
# 10     Hyderabad          Delivery              4061       2018-07-31
# 20     Hyderabad           Dine-in               966       2018-07-31
# 24     Hyderabad           Dine-in               965       2018-07-31
# 26     Hyderabad          Delivery              4068       2018-07-31
# ...          ...               ...               ...              ...
# 30198     Mumbai         Take Away              4055       2016-08-01
# 30201     Mumbai           Dine-in               978       2016-08-01
# 30212     Mumbai           Dine-in               970       2016-08-01
# 30213     Mumbai           Dine-in               965       2016-08-01
# 30226     Mumbai         Take Away              4056       2016-08-01
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %%
df[df["Avg_Discount_Percent_On_Discounted_Items"]>=1]
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 1      Hyderabad         Take Away              4064       2018-07-31
# 44     Hyderabad         Take Away              4056       2018-07-31
# 45     Hyderabad         Take Away              4055       2018-07-31
# 61     Hyderabad         Main Hall               971       2018-07-30
# 99     Hyderabad         Take Away              4057       2018-07-29
# ...          ...               ...               ...              ...
# 30180     Mumbai         Take Away              4057       2016-08-02
# 30207     Mumbai         Take Away               978       2016-08-01
# 30211     Mumbai           Dine-in               971       2016-08-01
# 30215     Mumbai         Take Away               965       2016-08-01
# 30227     Mumbai         Take Away              4058       2016-08-01
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %% [markdown]
# ## 6th question Groupby

# %%
g1 = df.groupby(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date'])['Quantity_Sold'].sum()
g1
# Out:
# City     Mapped_Sales_Type  Mapped_Item_Code  Transaction_Date
# Chennai  Bakery             4057              2017-08-05          110
#                             9978              2018-01-22          105
#          Delivery           4055              2017-08-04          377
#                                               2017-08-05          377
#                                               2017-08-06          638
#                                                                  ...
# Mumbai   Take Away          4068              2017-01-09          200
#                                               2017-01-10          199
#                                               2017-01-11          239
#                                               2017-01-12          233
#                                               2017-01-13          273
# Name: Quantity_Sold, Length: 30231, dtype: int64

# %%
g2 =df.groupby(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date'])['Median_Price'].median()
g2
# Out:
# City     Mapped_Sales_Type  Mapped_Item_Code  Transaction_Date
# Chennai  Bakery             4057              2017-08-05          223.0
#                             9978              2018-01-22          178.0
#          Delivery           4055              2017-08-04          260.0
#                                               2017-08-05          260.0
#                                               2017-08-06          260.0
#                                                                   ...
# Mumbai   Take Away          4068              2017-01-09          405.0
#                                               2017-01-10          405.0
#                                               2017-01-11          405.0
#                                               2017-01-12          405.0
#                                               2017-01-13          405.0
# Name: Median_Price, Length: 30231, dtype: float64

# %%
g3 = df.groupby(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date'])['Effective_Price'].median()
g3
# Out:
# City     Mapped_Sales_Type  Mapped_Item_Code  Transaction_Date
# Chennai  Bakery             4057              2017-08-05          221.000000
#                             9978              2018-01-22          154.250000
#          Delivery           4055              2017-08-04          264.113759
#                                               2017-08-05          264.138571
#                                               2017-08-06          264.223814
#                                                                      ...
# Mumbai   Take Away          4068              2017-01-09          424.140000
#                                               2017-01-10          424.140000
#                                               2017-01-11          424.140000
#                                               2017-01-12          424.140000
#                                               2017-01-13          423.201358
# Name: Effective_Price, Length: 30231, dtype: float64

# %% [markdown]
# ## 7th question notnull

# %%
df_subset3= pd.notnull(df['Effective_Price'])
df[df_subset3].tail(5)
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 30226  Mumbai         Take Away              4056       2016-08-01
# 30227  Mumbai         Take Away              4058       2016-08-01
# 30228  Mumbai           Dine-in               964       2016-08-01
# 30229  Mumbai         Take Away              4066       2016-08-01
# 30230  Mumbai          Delivery              4061       2016-08-01
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 30226            615         239.0                 0.14       232.033552
# 30227           1289         212.8                 0.14       202.575840
# 30228            140         933.0                 0.21      1063.855517
# 30229            179         501.0                 0.14       534.060000
# 30230            117         716.5                 0.15       780.810000
#
#        Percent_Quantity_With_Discount  \
# 30226                        0.013889
# 30227                        0.009338
# ...

# %% [markdown]
# ## 8th question subset 4

# %%
df_subset4 = df.loc[(df['City'] == 'Chennai') & ( df['Mapped_Sales_Type'] == 'Delivery')]
df_subset4
# Out:
#           City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 8379   Chennai          Delivery              4055       2018-02-05
# 8384   Chennai          Delivery              4068       2018-02-05
# 8387   Chennai          Delivery              4064       2018-02-05
# 8388   Chennai          Delivery              4058       2018-02-05
# 8392   Chennai          Delivery              4061       2018-02-05
# ...        ...               ...               ...              ...
# 16606  Chennai          Delivery              4057       2017-08-04
# 16609  Chennai          Delivery              4056       2017-08-04
# 16611  Chennai          Delivery              4059       2017-08-04
# 16612  Chennai          Delivery              4063       2017-08-04
# 16614  Chennai          Delivery              4066       2017-08-04
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 8379             544        281.10                 0.05       262.502194
# ...

# %% [markdown]
# ## 9 th question subset 5

# %%
df_subset5 = df[df['Day'].isin(['Mon', 'Tue', 'Wed'])]
df_subset5
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978       2018-07-31
# 1      Hyderabad         Take Away              4064       2018-07-31
# 2      Hyderabad         Main Hall               965       2018-07-31
# 3      Hyderabad           Express              9978       2018-07-31
# 4      Hyderabad           Express              1045       2018-07-31
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056       2016-08-01
# 30227     Mumbai         Take Away              4058       2016-08-01
# 30228     Mumbai           Dine-in               964       2016-08-01
# 30229     Mumbai         Take Away              4066       2016-08-01
# 30230     Mumbai          Delivery              4061       2016-08-01
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %% [markdown]
# ## 10th question

# %%
sample_loc = df.loc[(df['Percent_Quantity_With_Discount'] != '0.0')]
sample_loc.head()
# Out:
#         City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0  Hyderabad         Take Away              9978       2018-07-31
# 1  Hyderabad         Take Away              4064       2018-07-31
# 2  Hyderabad         Main Hall               965       2018-07-31
# 3  Hyderabad           Express              9978       2018-07-31
# 4  Hyderabad           Express              1045       2018-07-31
#
#    Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 0            167         187.0                 0.05       163.700000
# 1            368         602.0                 0.05       584.329105
# 2            694         263.0                 0.05       244.835163
# 3            140         263.0                 0.05       243.500000
# 4            139         392.0                 0.05       378.960000
#
#    Percent_Quantity_With_Discount  Avg_Discount_Percent_On_Discounted_Items  \
# ...

# %% [markdown]
# ## 11th question

# %%
df['Discount'] = [1 if x > 500 else 0.5 for x in df['Effective_Price']]
print(df)
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978       2018-07-31
# 1      Hyderabad         Take Away              4064       2018-07-31
# 2      Hyderabad         Main Hall               965       2018-07-31
# 3      Hyderabad           Express              9978       2018-07-31
# 4      Hyderabad           Express              1045       2018-07-31
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056       2016-08-01
# 30227     Mumbai         Take Away              4058       2016-08-01
# 30228     Mumbai           Dine-in               964       2016-08-01
# 30229     Mumbai         Take Away              4066       2016-08-01
# 30230     Mumbai          Delivery              4061       2016-08-01
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %% [markdown]
# ## 12th question

# %%
df = pd.read_csv("Demand_txn_updated.txt")
df['Percent_Quantity_With_Discount'].fillna(df['Percent_Quantity_With_Discount'].mean(), inplace=True)

# %%
df
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978        7/31/2018
# 1      Hyderabad         Take Away              4064        7/31/2018
# 2      Hyderabad         Main Hall               965        7/31/2018
# 3      Hyderabad           Express              9978        7/31/2018
# 4      Hyderabad           Express              1045        7/31/2018
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056         8/1/2016
# 30227     Mumbai         Take Away              4058         8/1/2016
# 30228     Mumbai           Dine-in               964         8/1/2016
# 30229     Mumbai         Take Away              4066         8/1/2016
# 30230     Mumbai          Delivery              4061         8/1/2016
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %%
df["Percent_Quantity_With_Discount"].isnull().sum()
# Out:
# 0
